# %% [markdown]
# # Causal Machine Learning with EconML

# %%
#!pip install econml
#!pip install ipywidgets

# %% [markdown]
# ## Paper
# Brantner, C. L., Nguyen, T. Q., Parikh, H., Zhao, C., Hong, H., & Stuart, E. A. (2025). Precision Mental Health: Predicting Heterogeneous Treatment Effects for Depression through Data Integration. arXiv preprint arXiv:2509.04604.
#
# https://arxiv.org/pdf/2509.04604

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from econml.metalearners import TLearner, SLearner, XLearner
import warnings
from sklearn.exceptions import ConvergenceWarning
warnings.filterwarnings("ignore", category=ConvergenceWarning)

# %%
# Generate synthetic data
np.random.seed(42)
n = 2000

# Descriptive statistics for Duke EHR sample
age_mean, age_sd = 44.8, 12.7
weight_mean, weight_sd = 201, 58.5
female_prob = 0.754
diabetes_prob = 0.207
hypothyroidism_prob = 0.111
anxiety_prob = 0.610
antidepressant_prob = 0.582
thyroid_med_prob = 0.093
severe_depression_prob = 0.268

# Generate synthetic features
age = np.random.normal(age_mean, age_sd, n).clip(18, 75)
weight = np.random.normal(weight_mean, weight_sd, n).clip(90, 350)
female = np.random.binomial(1, female_prob, n)
diabetes = np.random.binomial(1, diabetes_prob, n)
hypothyroidism = np.random.binomial(1, hypothyroidism_prob, n)
anxiety = np.random.binomial(1, anxiety_prob, n)
antidepressant = np.random.binomial(1, antidepressant_prob, n)
thyroid_med = np.random.binomial(1, thyroid_med_prob, n)
severe_depression = np.random.binomial(1, severe_depression_prob, n)

# Treatment assignment: duloxetine (0) or vortioxetine (1)
treatment = np.random.binomial(1, 0.5, n)

# Simulate outcome with true heterogeneity in tau(X)
# Outcome = "improvement" (higher is better)

# Baseline outcome mechanism mu(X): contributes to Y(0)
mu = (
    6.0
    + 0.01 * (age - 45)             # mild age trend in baseline improvement
    - 0.3 * anxiety                 # anxiety dampens baseline improvement
    + 0.8 * severe_depression   )    # severe cases have more "room to improve"

# Heterogeneous treatment effect tau(X): contributes to Y(1) - Y(0)
tau = (
    2.0
    + 0.015 * (age - 45)            # older → larger incremental benefit
    + 0.010 * (weight - 200)        # heavier → larger incremental benefit
    + 0.4 * female                  # modest gender effect
    + 0.7 * severe_depression       # severe → higher marginal benefit
    + 0.2 * female * severe_depression ) # interaction

# Noise
eps0 = np.random.normal(0, 1.0, n)
eps1 = np.random.normal(0, 1.0, n)

# Potential outcomes
Y0 = mu + eps0
Y1 = mu + tau + eps1

# Observed outcome under treatment assignment
outcome = np.where(treatment == 1, Y1, Y0)

# Create DataFrame
data = pd.DataFrame({
    'Age': age,
    'Weight': weight,
    'Female': female,
    'Diabetes': diabetes,
    'Hypothyroidism': hypothyroidism,
    'Anxiety': anxiety,
    'Antidepressant': antidepressant,
    'Thyroid_Med': thyroid_med,
    'Severe_Depression': severe_depression,
    'Treatment': treatment,        
    'Tau': tau,
    'MADRS_Change': outcome        })
print("Ground true of the treatment effect:", data['Tau'].mean())
data.head()
# Out:
# Ground true of the treatment effect: 2.5499546220634883
#          Age      Weight  Female  Diabetes  Hypothyroidism  Anxiety  \
# 0  51.108270  161.502071       1         0               0        1
# 1  43.044043  192.545658       1         0               0        1
# 2  53.025644  154.643435       0         0               0        1
# 3  64.142479  182.984251       1         0               0        1
# 4  41.826252   90.223542       1         0               0        1
#
#    Antidepressant  Thyroid_Med  Severe_Depression  Treatment       Tau  \
# 0               1            0                  0          0  2.106645
# 1               1            0                  0          0  2.296117
# 2               0            1                  0          0  1.666819
# 3               0            0                  0          1  2.516980
# 4               0            0                  0          1  1.254629
#
#    MADRS_Change
# 0      6.509078
# 1      4.451661
# 2      5.681384
# ...

# %%
covariates = ['Age','Weight','Female','Diabetes','Hypothyroidism','Anxiety','Antidepressant','Thyroid_Med','Severe_Depression'] 
train, test = train_test_split(data, test_size=0.3, random_state=42)
X_train = train[covariates].copy()
y_train = train['MADRS_Change']
T_train = train['Treatment']
X_test = test[covariates].copy()
y_test = test['MADRS_Change']
T_test = test['Treatment']

# %% [markdown]
# ### S-Learner: Manual

# %%
X_train_S = train.drop(columns=['MADRS_Change']).copy()
X_test_S = test.drop(columns=['MADRS_Change']).copy()
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train_S, y_train)
pred_S_treated = model.predict(X_test_S.assign(Treatment=1))
pred_S_control = model.predict(X_test_S.assign(Treatment=0))
CATE_S = pred_S_treated - pred_S_control

# %% [markdown]
# #### Validation: ATE

# %%
# Scatter plot
def scatter_plot(true_tau, pred_tau):
    plt.figure(figsize=(4,4))
    sns.scatterplot(x=true_tau, y=pred_tau, s=18, alpha=0.5, edgecolor=None)
    lims = [min(true_tau.min(), pred_tau.min()), max(true_tau.max(), pred_tau.max())]
    plt.plot(lims, lims, 'r--', lw=1.5, label='45° line')
    plt.xlim(lims); plt.ylim(lims)
    plt.xlabel('True Tau(X)')
    plt.ylabel('Predicted Tau(X)')
    plt.title('True CATE vs. Predicted CATE')
    plt.legend()
    plt.tight_layout()
    plt.show()

print(f"TRUE ATE (overall):        {test['Tau'].mean():8.2f}")
print(f"ESTIMATED ATE (S-learner): {np.mean(CATE_S):8.2f}")
scatter_plot(true_tau = test['Tau'], pred_tau = CATE_S)
# Out:
# TRUE ATE (overall):            2.60
# ESTIMATED ATE (S-learner):     2.47

# %% [markdown]
# ### S-Learner: EconML

# %%
# Base model for E[Y | X, W]
outcome_model = RandomForestRegressor(n_estimators=100, random_state=42)
# Initialize S-Learner with the outcome model
s_learner = SLearner(overall_model=outcome_model)

# Fit on training data
s_learner.fit(Y=y_train, T=T_train, X=X_train)
# Estimate individual CATE on the test set
CATE_S = s_learner.effect(X_test)
# Out:
# /opt/anaconda3/envs/book_ci/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %% [markdown]
# #### Validation

# %%
print(f"TRUE ATE (overall):        {test['Tau'].mean():8.2f}")
print(f"ESTIMATED ATE (S-learner): {np.mean(CATE_S):8.2f}")
scatter_plot(true_tau = test['Tau'], pred_tau = CATE_S)
# Out:
# TRUE ATE (overall):            2.60
# ESTIMATED ATE (S-learner):     2.49

# %% [markdown]
# ### T-Learner: Manual

# %%
X_train_treated = X_train[train['Treatment']==1]
X_train_untreated = X_train[train['Treatment']==0]
y_train_treated = y_train[train['Treatment']==1]
y_train_untreated = y_train[train['Treatment']==0]

# %%
# -------------------------------
# T-Learner: Separate models for treated and control
# -------------------------------
model_treated = RandomForestRegressor(n_estimators=100, random_state=42)
model_control = RandomForestRegressor(n_estimators=100, random_state=42)

model_treated.fit(X_train_treated, y_train_treated)
model_control.fit(X_train_untreated, y_train_untreated)
# Out:
# RandomForestRegressor(random_state=42)

# %%
pred_T_treated = model_treated.predict(X_test)
pred_T_control = model_control.predict(X_test)
CATE_T = pred_T_treated - pred_T_control

# %% [markdown]
# #### Validation

# %%
print(f"TRUE ATE (overall):        {test['Tau'].mean():8.2f}")
print(f"ESTIMATED ATE (S-learner): {np.mean(CATE_T):8.2f}")
scatter_plot(true_tau = test['Tau'], pred_tau = CATE_T)
# Out:
# TRUE ATE (overall):            2.60
# ESTIMATED ATE (S-learner):     2.50

# %% [markdown]
# ### T-Learner: EconML

# %%
base_model = RandomForestRegressor(n_estimators=100, random_state=42)
t_learner = TLearner(models=base_model)
t_learner.fit(Y=y_train, T=T_train, X=X_train)
CATE_T = t_learner.effect(X_test)
# Out:
# /opt/anaconda3/envs/book_ci/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %% [markdown]
# #### Validation

# %%
print(f"TRUE ATE (overall):        {test['Tau'].mean():8.2f}")
print(f"ESTIMATED ATE (S-learner): {np.mean(CATE_T):8.2f}")
scatter_plot(true_tau = test['Tau'], pred_tau = CATE_T)
# Out:
# TRUE ATE (overall):            2.60
# ESTIMATED ATE (S-learner):     2.50

# %% [markdown]
# ### X-Learner: Manual

# %%
# X-Learner
D1 = y_train_treated - model_control.predict(X_train_treated)
D0 = model_treated.predict(X_train_untreated) - y_train_untreated

model_D1 = RandomForestRegressor(n_estimators=100, random_state=42)
model_D0 = RandomForestRegressor(n_estimators=100, random_state=42)
model_D1.fit(X_train_treated, D1)
model_D0.fit(X_train_untreated, D0)
CATE_X = 0.5*model_D1.predict(X_test) + 0.5*model_D0.predict(X_test)

# %% [markdown]
# #### Validation

# %%
print(f"TRUE ATE (overall):        {test['Tau'].mean():8.2f}")
print(f"ESTIMATED ATE (S-learner): {np.mean(CATE_X):8.2f}")
scatter_plot(true_tau = test['Tau'], pred_tau = CATE_X)
# Out:
# TRUE ATE (overall):            2.60
# ESTIMATED ATE (S-learner):     2.49

# %% [markdown]
# ### X-Learner: EconML

# %%
mu_model = RandomForestRegressor(n_estimators=100, random_state=42)
tau_model = RandomForestRegressor(n_estimators=100, random_state=42)
x_learner = XLearner(models=mu_model, cate_models=tau_model)
x_learner.fit(Y=y_train, T=T_train, X=X_train)
CATE_X = x_learner.effect(X_test)
# Out:
# /opt/anaconda3/envs/book_ci/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
print(f"TRUE ATE (overall):        {test['Tau'].mean():8.2f}")
print(f"ESTIMATED ATE (S-learner): {np.mean(CATE_X):8.2f}")
scatter_plot(true_tau = test['Tau'], pred_tau = CATE_X)
# Out:
# TRUE ATE (overall):            2.60
# ESTIMATED ATE (S-learner):     2.49

# %% [markdown]
# ### Feature Importance for the X-Learner CATE Drivers
#
# Use SHAP values or permutation importance on the X-Learner models to see which covariates drive heterogeneity.

# %%
import shap

# 1) Explain each stage-2 model separately
expl_D1 = shap.TreeExplainer(model_D1, feature_perturbation="interventional")
expl_D0 = shap.TreeExplainer(model_D0, feature_perturbation="interventional")

shap_D1 = expl_D1.shap_values(X_test)   # shape: (n_samples, p)
shap_D0 = expl_D0.shap_values(X_test)   # shape: (n_samples, p)

shap_tau = 0.5 * shap_D1 + 0.5 * shap_D0 
shap.summary_plot(shap_tau, X_test, show=True)
# Out:
# /opt/anaconda3/envs/book_ci/lib/python3.12/site-packages/shap/explainers/_tree.py:253: FutureWarning: In the future, passing feature_perturbation='interventional' without providing a background dataset will raise an error. Please provide a background dataset to continue using the interventional approach or set feature_perturbation='auto' to automatically switch approaches.
#   warnings.warn(
# /var/folders/b8/hq7p21n142n321y966q8j1600000gn/T/ipykernel_47310/3877471162.py:11: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(shap_tau, X_test, show=True)

# %%
feature_name = 'Weight'
shap.dependence_plot(feature_name, shap_tau, X_test, interaction_index="auto", show=True)

# %%
covariates = ['Female','Diabetes','Hypothyroidism','Anxiety',
              'Antidepressant','Severe_Depression']

# Choose the predicted CATE to plot (replace with CATE_X or another)
CATE_pred = CATE_X  # <- your predicted CATE aligned to `test`

n_rows, n_cols = 4, 2
n_plots = n_rows * n_cols
labels = ['0', '1']  # assuming binary indicators
width = 0.36

fig, axes = plt.subplots(2, 3, figsize=(12, 6))
axes = axes.flatten()

for i, cov in enumerate(covariates[:n_plots]):
    ax = axes[i]
    df_plot = pd.DataFrame({
        cov: test[cov].values,
        'true': test['Tau'].values,
        'pred': CATE_pred})
    grp = df_plot.groupby(cov).agg(true_mean=('true', 'mean'),
                                   pred_mean=('pred', 'mean'))
    x = np.arange(2)
    ax.bar(x - width/2, grp['true_mean'].values, width, label='True Tau', color='#6baed6')
    ax.bar(x + width/2, grp['pred_mean'].values, width, label='Predicted Tau', color='#fd8d3c')

    ax.set_xticks(x)
    ax.set_xticklabels(labels)
    ax.set_title(f'{cov}: Mean CATE')
    ax.set_ylabel('CATE')
    ax.grid(axis='y', alpha=0.2)

# Single legend for the whole figure
handles, legend_labels = axes[0].get_legend_handles_labels()
fig.legend(handles, legend_labels, loc='upper center', ncol=2, frameon=False)

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %% [markdown]
# ### Model Prediction in Action
# Sort patients by predicted CATE and display top/bottom 10 for targeting interventions.

# %%
for_action = test.copy()
for_action['CATE_X'] = CATE_X

# Sort patients by predicted CATE (X-Learner)
ranked = for_action.sort_values(by='CATE_X', ascending=False)

# Top 10 patients (highest predicted benefit from treatment)
top_10 = ranked.head(10)

# Bottom 10 patients (lowest predicted benefit)
bottom_10 = ranked.tail(10)

# Display tables
print("Top 10 patients ranked by predicted CATE (X-Learner):")
print(top_10[['Age','Weight','Female','Anxiety','Antidepressant','Severe_Depression', 'CATE_X']])

print("\nBottom 10 patients ranked by predicted CATE (X-Learner):")
print(bottom_10[['Age','Weight','Female','Anxiety','Antidepressant','Severe_Depression','CATE_X']])
# Out:
# Top 10 patients ranked by predicted CATE (X-Learner):
#             Age      Weight  Female  Anxiety  Antidepressant  \
# 305   46.290058  350.000000       1        1               0
# 1686  38.899360  346.383610       0        1               0
# 120   54.846106  342.138002       0        1               1
# 481   32.664636  301.583608       1        0               1
# 1233  75.000000  312.818017       1        1               0
# 1624  68.590882  312.019370       1        1               1
# 506   37.276597  350.000000       0        0               0
# 1319  42.425464  336.722382       1        0               0
# 544   18.000000  342.962914       0        1               1
# 1512  35.696357  301.154357       1        1               0
#
#       Severe_Depression    CATE_X
# 305                   0  5.435084
# 1686                  0  5.098850
# 120                   0  4.974618
# 481                   1  4.928062
# 1233                  0  4.874148
# ...
